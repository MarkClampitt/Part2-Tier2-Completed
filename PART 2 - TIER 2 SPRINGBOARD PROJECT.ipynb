# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# scipi is a library for statistical tests and visualizations 
from scipy import stats
# random enables us to generate random numbers
import random

# %%
# Now that the files are saved, we want to load them into Python using read_csv and pandas.

# Create a variable called google, and store in it the path of the csv file that contains your google dataset. 
# If your dataset is in the same folder as this notebook, the path will simply be the name of the file. 
google = "googleplaystore.csv"

# Read the csv file into a data frame called Google using the read_csv() pandas method.
Google = pd.read_csv("googleplaystore.csv", sep=",")

# Using the head() pandas method, observe the first three entries.
Google.head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M     10,000+  Free     0       Everyone
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# Create a variable called apple, and store in it the path of the csv file that contains your apple dataset. 
apple = "AppleStore.csv"

# Read the csv file into a pandas DataFrame object called Apple.
Apple = pd.read_csv("AppleStore.csv", sep=",")
# Observe the first three entries like you did with your other data. 
Apple.head(3)
# Out:
#    Unnamed: 0         id                                       track_name  \
# 0           1  281656475                                  PAC-MAN Premium
# 1           2  281796108                        Evernote - stay organized
# 2           3  281940292  WeatherBug - Local Weather, Radar, Maps, Alerts
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
#
#    user_rating  user_rating_ver    ver cont_rating   prime_genre  \
# 0          4.0              4.5  6.3.5          4+         Games
# 1          4.0              3.5  8.2.2          4+  Productivity
# 2          3.5              4.5  5.0.0          4+       Weather
#
#    sup_devices.num  ipadSc_urls.num  lang.num  vpp_lic
# 0               38                5        10        1
# 1               37                5        23        1
# 2               37                5         3        1

# %%
# Subset our DataFrame object Google by selecting just the variables ['Category', 'Rating', 'Reviews', 'Price']
sub_Google = Google[['Category', 'Rating', 'Reviews','Price']]
sub_Google.head(3)
# Check the first three entries
# Out:
#          Category  Rating Reviews Price
# 0  ART_AND_DESIGN     4.1     159     0
# 1  ART_AND_DESIGN     3.9     967     0
# 2  ART_AND_DESIGN     4.7   87510     0

# %%
# Do the same with our Apple object, selecting just the variables ['prime_genre', 'user_rating', 'rating_count_tot', 'price']
sub_Apple = Apple[['prime_genre','user_rating', 'rating_count_tot','price']] 

# Let's check the first three entries
sub_Apple.head(3)
# Out:
#     prime_genre  user_rating  rating_count_tot  price
# 0         Games          4.0             21292   3.99
# 1  Productivity          4.0            161065   0.00
# 2       Weather          3.5            188583   0.00

# %%
# Using the dtypes feature of pandas DataFrame objects, check out the data types within our Apple dataframe.
# Are they what you expect?
Apple.dtypes
# Out:
# Unnamed: 0            int64
# id                    int64
# track_name           object
# size_bytes            int64
# currency             object
# price               float64
# rating_count_tot      int64
# rating_count_ver      int64
# user_rating         float64
# user_rating_ver     float64
# ver                  object
# cont_rating          object
# prime_genre          object
# sup_devices.num       int64
# ipadSc_urls.num       int64
# lang.num              int64
# vpp_lic               int64
# dtype: object

# %%
# Using the same dtypes feature, check out the data types of our Google dataframe. 
Google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Use the unique() pandas method on the Price column to check its unique values. 
Google['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', 'Everyone', '$1.20', '$1.04'], dtype=object)

# %%
# Let's check which data points have the value 'Everyone' for the 'Price' column by subsetting our Google dataframe.

# Subset the Google dataframe on the price column. 
# To be sure: you want to pick out just those rows whose value for the 'Price' column is just 'Everyone'. 
Google[Google['Price']=='Everyone']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
 #Let's eliminate that row. 

# Subset our Google dataframe to pick out just those rows whose value for the 'Price' column is NOT 'Everyone'. 
# Reassign that subset to the Google variable. 
# You can do this in two lines or one. Your choice! 
NoEveryone_Google = Google[Google['Price'] != 'Everyone']

# Check again the unique values of Google
NoEveryone_Google['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
#        '$394.99', '$1.26', '$1.20', '$1.04'], dtype=object)

# %%
# Let's create a variable called nosymb.
# This variable will take the Price column of Google and apply the str.replace() method. 
# Remember: we want to find '$' and replace it with nothing, so we'll have to write approrpiate arguments to the method to achieve this. 
nosymb = NoEveryone_Google['Price'].str.replace('$',' ')

# Now we need to do two things:
# i. Make the values in the nosymb variable numeric using the to_numeric() pandas method.
# ii. Assign this new set of numeric, dollar-sign-less values to Google['Price']. 
# You can do this in one line if you wish.
NoEveryone_Google['Price'] = pd.to_numeric(nosymb)
# Out:
# <ipython-input-123-653b8d9205c4>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   nosymb = NoEveryone_Google['Price'].str.replace('$',' ')
# <ipython-input-123-653b8d9205c4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NoEveryone_Google['Price'] = pd.to_numeric(nosymb)

# %%
NoEveryone_Google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Convert the 'Reviews' column to a numeric data type. 
# Use the method pd.to_numeric(), and save the result in the same column.
NoEveryone_Google['Reviews'] = pd.to_numeric(NoEveryone_Google['Reviews'])
# Out:
# <ipython-input-125-125ba74c2b3c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NoEveryone_Google['Reviews'] = pd.to_numeric(NoEveryone_Google['Reviews'])

# %%
# Let's check the data types of Google again
NoEveryone_Google.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size               object
# Installs           object
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# Create a column called 'platform' in both the Apple and Google dataframes. 
# Add the value 'apple' and the value 'google' as appropriate. 
Apple['platform'] = apple
Google['platform'] = google

# %%
# Create a variable called old_names where you'll store the column names of the Apple dataframe. 
# Use the feature .columns.
old_names = Apple.columns

# Create a variable called new_names where you'll store the column names of the Google dataframe. 
new_names = NoEveryone_Google.columns

# Use the rename() DataFrame method to change the columns names. 
# In the columns parameter of the rename() method, use this construction: dict(zip(old_names,new_names)).
Apple = Apple.rename(columns = dict(zip(old_names,new_names)))

# %%
# Let's use the append() method to append Apple to Google. 
# Make Apple the first parameter of append(), and make the second parameter just: ignore_index = True.
df = Google.append(Apple, ignore_index = True)

# Using the sample() method with the number 12 passed to it, check 12 random points of your dataset.
df.sample(12)
# Out:
#                              App            Category  \
# 4009                C-SPAN Radio              FAMILY
# 3671     Video Player All Format       VIDEO_PLAYERS
# 7517                 CL Notifier               TOOLS
# 7931         Amazing Fart Sounds              FAMILY
# 4695   BTS V LINE Launcher theme     PERSONALIZATION
# 1966            Candy Crush Saga                GAME
# 1348    Pregnancy & Baby Tracker  HEALTH_AND_FITNESS
# 2201          DreamWorks Friends              FAMILY
# 15566                       6072          1058528141
# 3384    ASUS Cover for ZenFone 2     PERSONALIZATION
# 8235      DB for Fallout Shelter              FAMILY
# 12598                       2042           593658634
#
#                                                 Rating    Reviews  \
# 4009                                               3.6        608
# 3671                                               4.8     259003
# 7517                                               5.0         36
# 7931                                               4.0      28136
# 4695                                               4.8       3283
# 1966                                               4.4   22430188
# 1348                                               4.6      48286
# 2201                                               3.6       1042
# 15566  War Machines: 3D Multiplayer Tank Shooting Game  163080192
# 3384                                               4.4      43960
# 8235                                               4.0       3323
# 12598                                      Trenches II  256817152
#
#                      Size      Installs   Type Price Content Rating  \
# 4009                 5.4M      100,000+   Free     0       Everyone
# 3671   Varies with device   10,000,000+   Free     0       Everyone
# 7517                 3.2M          100+   Free     0           Teen
# 7931   Varies with device    5,000,000+   Free     0       Everyone
# 4695                 3.6M      100,000+   Free     0       Everyone
# 1966                  74M  500,000,000+   Free     0       Everyone
# 1348   Varies with device    1,000,000+   Free     0       Everyone
# 2201                  48M      100,000+   Free     0       Everyone
# 15566                 USD           0.0  11325   172            5.0
# 3384                 9.8M   10,000,000+   Free     0       Everyone
# 8235                  47M      100,000+   Free     0       Everyone
# 12598                 USD          0.99   2232    70            4.5
#
#                           Genres      Last Updated         Current Ver  \
# 4009               Entertainment      May 17, 2018               4.3.2
# 3671     Video Players & Editors    August 3, 2018  Varies with device
# 7517                       Tools    August 2, 2017                 1.0
# 7931                      Casual   August 24, 2017  Varies with device
# 4695             Personalization  October 17, 2014                 4.1
# 1966                      Casual      July 5, 2018           1.129.0.2
# 1348            Health & Fitness     July 27, 2018  Varies with device
# 2201   Role Playing;Pretend Play    August 4, 2017                 2.5
# 15566                        4.5             2.0.6                 12+
# 3384             Personalization  December 1, 2017     2.0.0.39_171124
# 8235                  Simulation    March 29, 2018                 1.9
# 12598                        3.5               1.4                 12+
#
#               Android Ver             platform  sup_devices.num  \
# 4009           4.1 and up  googleplaystore.csv              NaN
# 3671           4.3 and up  googleplaystore.csv              NaN
# 7517           4.0 and up  googleplaystore.csv              NaN
# 7931   Varies with device  googleplaystore.csv              NaN
# 4695         4.0.3 and up  googleplaystore.csv              NaN
# 1966           4.1 and up  googleplaystore.csv              NaN
# 1348   Varies with device  googleplaystore.csv              NaN
# 2201           4.3 and up  googleplaystore.csv              NaN
# 15566               Games       AppleStore.csv             38.0
# 3384           5.0 and up  googleplaystore.csv              NaN
# 8235           4.0 and up  googleplaystore.csv              NaN
# 12598               Games       AppleStore.csv             40.0
#
#        ipadSc_urls.num  lang.num  vpp_lic
# 4009               NaN       NaN      NaN
# 3671               NaN       NaN      NaN
# 7517               NaN       NaN      NaN
# 7931               NaN       NaN      NaN
# 4695               NaN       NaN      NaN
# 1966               NaN       NaN      NaN
# 1348               NaN       NaN      NaN
# 2201               NaN       NaN      NaN
# 15566              5.0       9.0      1.0
# 3384               NaN       NaN      NaN
# 8235               NaN       NaN      NaN
# 12598              5.0       5.0      1.0

# %%
# Lets check first the dimesions of df before droping `NaN` values. Use the .shape feature. 
print(df.shape)

# Use the dropna() method to eliminate all the NaN values, and overwrite the same dataframe with the result. 
# Note: dropna() by default removes all rows containing at least one NaN. 
df =  df.dropna(how='all')

# Check the new dimesions of our dataframe. 
print(df.shape)
df.sample(12)
# Out:
# (18038, 18)
# (18038, 18)
#                                                      App            Category  \
# 11096                                                289           338137227
# 830            Mango Languages: Lovable Language Courses           EDUCATION
# 3783                                        Reuters News  NEWS_AND_MAGAZINES
# 3763                          Dezeen Magazine RSS Reader  NEWS_AND_MAGAZINES
# 7203                            C-E Federal Credit Union             FINANCE
# 1399                            Lark - 24/7 Health Coach  HEALTH_AND_FITNESS
# 10450                     Police Field Interview FI Card        PRODUCTIVITY
# 2947   Fotor Photo Editor - Photo Collage & Photo Eff...         PHOTOGRAPHY
# 15846                                               6554          1068419726
# 8669                      DO YOU KNOW THE WAY Soundboard              FAMILY
# 16457                                               7605          1090617661
# 13602                                               3292           891596226
#
#                                                   Rating    Reviews  \
# 11096  Walmart: Free 2-Day Shipping,* Easy Store Shop...  146507776
# 830                                                  4.0       4815
# 3783                                                 4.3      13169
# 3763                                                 4.3        350
# 7203                                                 NaN          1
# 1399                                                 4.1       3405
# 10450                                                4.5        112
# 2947                                                 4.5     597068
# 15846                                              うねうね糸   16157696
# 8669                                                 4.5       1007
# 16457    Steve - The Jumping Dinosaur Widget Arcade Game   26888192
# 13602                                华尔街见闻（专业版）-全球财经新闻精选   71386112
#
#                      Size     Installs   Type  Price Content Rating  \
# 11096                 USD          0.0  70286     51            3.0
# 830                   19M     500,000+   Free      0       Everyone
# 3783                  25M   1,000,000+   Free      0   Everyone 10+
# 3763                  14M      10,000+   Free      0       Everyone
# 7203                 2.8M         500+   Free      0       Everyone
# 1399                  51M     100,000+   Free      0       Everyone
# 10450                2.4M       1,000+   Paid  $7.99       Everyone
# 2947   Varies with device  10,000,000+   Free      0       Everyone
# 15846                 USD          0.0      0      0            0.0
# 8669                 5.2M     100,000+   Free      0       Everyone
# 16457                 USD          0.0   7751     39            4.5
# 13602                 USD         0.99     11      0            3.5
#
#                  Genres    Last Updated         Current Ver  \
# 11096               4.0            17.8                  4+
# 830           Education   July 17, 2018               4.2.3
# 3783   News & Magazines    June 6, 2018               3.4.4
# 3763   News & Magazines   July 22, 2018             3.000.1
# 7203            Finance  March 23, 2018               3.0.6
# 1399   Health & Fitness   July 25, 2018           4.5.1.123
# 10450      Productivity  March 16, 2017                 3.0
# 2947        Photography    July 9, 2018  Varies with device
# 15846               0.0           1.0.1                  4+
# 8669      Entertainment    July 1, 2018                 7.0
# 16457               4.5           1.6.1                  4+
# 13602               0.0           4.0.2                  4+
#
#               Android Ver             platform  sup_devices.num  \
# 11096            Shopping       AppleStore.csv             37.0
# 830            4.2 and up  googleplaystore.csv              NaN
# 3783           4.1 and up  googleplaystore.csv              NaN
# 3763           4.2 and up  googleplaystore.csv              NaN
# 7203           4.1 and up  googleplaystore.csv              NaN
# 1399           4.4 and up  googleplaystore.csv              NaN
# 10450        4.0.3 and up  googleplaystore.csv              NaN
# 2947   Varies with device  googleplaystore.csv              NaN
# 15846               Games       AppleStore.csv             38.0
# 8669           4.1 and up  googleplaystore.csv              NaN
# 16457               Games       AppleStore.csv             37.0
# 13602                News       AppleStore.csv             37.0
#
#        ipadSc_urls.num  lang.num  vpp_lic
# 11096              0.0       1.0      1.0
# 830                NaN       NaN      NaN
# 3783               NaN       NaN      NaN
# 3763               NaN       NaN      NaN
# 7203               NaN       NaN      NaN
# 1399               NaN       NaN      NaN
# 10450              NaN       NaN      NaN
# 2947               NaN       NaN      NaN
# 15846              5.0       2.0      1.0
# 8669               NaN       NaN      NaN
# 16457              5.0       3.0      1.0
# 13602              5.0       2.0      1.0

# %%
# Subset your df to pick out just those rows whose value for 'Reviews' is equal to 0. 
# Do a count() on the result. 
df[df['Reviews'] == '0'].count()
# Out:
# App                596
# Category           596
# Rating               0
# Reviews            596
# Size               596
# Installs           596
# Type               595
# Price              596
# Content Rating     596
# Genres             596
# Last Updated       596
# Current Ver        595
# Android Ver        596
# platform           596
# sup_devices.num      0
# ipadSc_urls.num      0
# lang.num             0
# vpp_lic              0
# dtype: int64

# %%
# Eliminate the points that have 0 reviews.
# An elegant way to do this is to assign df the result of picking out just those rows in df whose value for 'Reviews' is NOT 0.
df = df[df['Reviews'] != 0]

# %%
# To summarize analytically, let's use the groupby() method on our df.
# For its parameters, let's assign its 'by' parameter 'platform', and then make sure we're seeing 'Rating' too. 
# Finally, call describe() on the result. We can do this in one line, but this isn't necessary. 
df.groupby('platform')['Rating'].describe()
# Out:
#                       count unique                top    freq
# platform
# AppleStore.csv         7197   7195  VR Roller Coaster       2
# googleplaystore.csv  9367.0   40.0                4.4  1109.0

# %%
# Call the boxplot() method on our df.
# Set the parameters: by = 'platform' and column = ['Rating'].
df.boxplot(by = 'platform', column = ['Rating'], grid=False, rot=45, fontsize=15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-7a16d17c765d> in <module>
#       1 # Call the boxplot() method on our df.
#       2 # Set the parameters: by = 'platform' and column = ['Rating'].
# ----> 3 df.boxplot(by= 'platform', column =['Rating'], grid=False, rot=45, fontsize=15)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     492 ):
#     493     plot_backend = _get_plot_backend(backend)
# --> 494     return plot_backend.boxplot_frame(
#     495         self,
#     496         column=column,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     383     import matplotlib.pyplot as plt
#     384
# --> 385     ax = boxplot(
#     386         self,
#     387         column=column,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     335         # Prefer array return type for 2-D plots to match the subplot layout
#     336         # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 337         result = _grouped_plot_by_column(
#     338             plot_group,
#     339             data,
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     214         gp_col = grouped[col]
#     215         keys, values = zip(*gp_col)
# --> 216         re_plotf = plotf(keys, values, ax, **kwargs)
#     217         ax.set_title(col)
#     218         ax.set_xlabel(pprint_thing(by))
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/boxplot.py in plot_group(keys, values, ax)
#     301         keys = [pprint_thing(x) for x in keys]
#     302         values = [np.asarray(remove_na_arraylike(v), dtype=object) for v in values]
# --> 303         bp = ax.boxplot(values, **kwds)
#     304         if fontsize is not None:
#     305             ax.tick_params(axis="both", labelsize=fontsize)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder)
#    3681             bootstrap = rcParams['boxplot.bootstrap']
#    3682
# -> 3683         bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3684                                        labels=labels, autorange=autorange)
#    3685         if notch is None:
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1175
#    1176         # arithmetic mean
# -> 1177         stats['mean'] = np.mean(x)
#    1178
#    1179         # medians and quartiles
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims, where)
#    3417             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3418
# -> 3419     return _methods._mean(a, axis=axis, dtype=dtype,
#    3420                           out=out, **kwargs)
#    3421
#
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     188             ret = ret.dtype.type(ret / rcount)
#     189     else:
# --> 190         ret = ret / rcount
#     191
#     192     return ret
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
